# %% [markdown]
# # Public APIs
# https://github.com/public-apis/public-apis

# %%
import requests as r

# %% [markdown]
# ## Dictionary API
#
# https://dictionaryapi.dev/

# %%
# dictionary API
word = 'hello'

url = f'https://api.dictionaryapi.dev/api/v2/entries/en/{word}'
resp = r.get(url)

data = resp.json()
data
# Out:
# [{'word': 'hello',
#   'phonetics': [{'audio': 'https://api.dictionaryapi.dev/media/pronunciations/en/hello-au.mp3',
#     'sourceUrl': 'https://commons.wikimedia.org/w/index.php?curid=75797336',
#     'license': {'name': 'BY-SA 4.0',
#      'url': 'https://creativecommons.org/licenses/by-sa/4.0'}},
#    {'text': '/həˈləʊ/',
#     'audio': 'https://api.dictionaryapi.dev/media/pronunciations/en/hello-uk.mp3',
#     'sourceUrl': 'https://commons.wikimedia.org/w/index.php?curid=9021983',
#     'license': {'name': 'BY 3.0 US',
#      'url': 'https://creativecommons.org/licenses/by/3.0/us'}},
#    {'text': '/həˈloʊ/', 'audio': ''}],
#   'meanings': [{'partOfSpeech': 'noun',
#     'definitions': [{'definition': '"Hello!" or an equivalent greeting.',
#       'synonyms': [],
#       'antonyms': []}],
#     'synonyms': ['greeting'],
#     'antonyms': []},
#    {'partOfSpeech': 'verb',
#     'definitions': [{'definition': 'To greet with "hello".',
#       'synonyms': [],
#       'antonyms': []}],
#     'synonyms': [],
#     'antonyms': []},
#    {'partOfSpeech': 'interjection',
#     'definitions': [{'definition': 'A greeting (salutation) said when meeting someone or acknowledging someone’s arrival or presence.',
#       'synonyms': [],
#       'antonyms': [],
#       'example': 'Hello, everyone.'},
#      {'definition': 'A greeting used when answering the telephone.',
#       'synonyms': [],
#       'antonyms': [],
#       'example': 'Hello? How may I help you?'},
#      {'definition': 'A call for response if it is not clear if anyone is present or listening, or if a telephone conversation may have been disconnected.',
#       'synonyms': [],
#       'antonyms': [],
#       'example': 'Hello? Is anyone there?'},
#      {'definition': 'Used sarcastically to imply that the person addressed or referred to has done something the speaker or writer considers to be foolish.',
#       'synonyms': [],
#       'antonyms': [],
#       'example': 'You just tried to start your car with your cell phone. Hello?'},
#      {'definition': 'An expression of puzzlement or discovery.',
#       'synonyms': [],
#       'antonyms': [],
#       'example': 'Hello! What’s going on here?'}],
#     'synonyms': [],
#     'antonyms': ['bye', 'goodbye']}],
#   'license': {'name': 'CC BY-SA 3.0',
#    'url': 'https://creativecommons.org/licenses/by-sa/3.0'},
#   'sourceUrls': ['https://en.wiktionary.org/wiki/hello']}]

# %% [markdown]
# ## Open Weather API
# https://openweathermap.org/current

# %%
# appid = '6b462dce2459960580f0585c96971d9b'
appid = 'ffb7b9808e07c9135bdcc7d1e867253d'

lat, lon = 59.85925856966359, 17.621534222123945

params = {
    'lat' : lat,
    'lon' : lon,
    'appid' : appid,
}

url = f'https://api.openweathermap.org/data/2.5/weather'
resp = r.get(url, params=params)

data = resp.json()

data
# Out:
# {'coord': {'lon': 17.6215, 'lat': 59.8593},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 274.14,
#   'feels_like': 274.14,
#   'temp_min': 274.14,
#   'temp_max': 276.18,
#   'pressure': 1026,
#   'humidity': 80},
#  'visibility': 10000,
#  'wind': {'speed': 0, 'deg': 0},
#  'clouds': {'all': 0},
#  'dt': 1648067697,
#  'sys': {'type': 1,
#   'id': 1731,
#   'country': 'SE',
#   'sunrise': 1648010561,
#   'sunset': 1648055371},
#  'timezone': 3600,
#  'id': 2666219,
#  'name': 'Uppsala Municipality',
#  'cod': 200}

# %%
resp.url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?lat=59.85925856966359&lon=17.621534222123945&appid=ffb7b9808e07c9135bdcc7d1e867253d'

# %% [markdown]
# ## NewsAPI
#
# https://newsapi.org/docs/endpoints/top-headlines

# %%
api_key = 'c91677e774064a0aad807a2cf3ea4821'

url = 'https://newsapi.org/v2/top-headlines'
params = {
    'apiKey' : api_key,
    'country' : 'us'
}

resp = r.get(url, params=params)

data = resp.json()


for article in data['articles']:

    title = article['title']
    desc = article['description']
    content = article['content']
    
    print('-'*50)
    print('\nTitle:', title)
    print('\nDesc:', desc)
    print('\nContent:', content)
# Out:
# --------------------------------------------------
#
# Title: US formally declares Russian military has committed war crimes in Ukraine - CNN
#
# Desc: The US government has formally declared that members of the Russian armed forces have committed war crimes in Ukraine, Secretary of State Antony Blinken said in a statement Wednesday.
#
# Content: (CNN)The US government has formally declared that members of the Russian armed forces have committed war crimes in Ukraine, Secretary of State Antony Blinken said in a statement Wednesday.
# The offic… [+1613 chars]
# --------------------------------------------------
#
# Title: As many as 15,000 Russian troops have been killed in Ukraine, NATO says; US accuses Russia of war crimes: Live updates - USA TODAY
#
# Desc: As many as 15,000 Russian troops have been killed since the invasion of Ukraine began four weeks ago. Latest news.
#
# Content: As many as 15,000 Russian troops have been killed since the invasion of Ukraine began four weeks ago, according to NATO's first estimate.
# Russia has suffered 30,000 to 40,000 battlefield casualties,… [+11469 chars]
# --------------------------------------------------
#
# Title: Chiefs trade Tyreek Hill to Dolphins for five draft picks, including a 2022 first-rounder - CBS Sports
#
# Desc: Another big-name blockbuster, in case you were getting bored
#
# Content: Another day, another big name on the move in the NFL. After failed efforts to strike a new contract with Tyreek Hill, the Chiefs have traded the All-Pro wide receiver to the Dolphins, as ESPN and NFL… [+3934 chars]
# --------------------------------------------------
#
# Title: Ketanji Brown Jackson hearings: Graham, Jackson spar over child pornography sentencing: live updates - USA TODAY
#
# Desc: Judge Ketanji Brown Jackson faces a second day of questions from senators. If confirmed, she would be the first Black woman on the U.S. Supreme Court.
#
# Content: Story Highlights
# <ul><li>Gallup Poll finds 58% of Americans back Jackson's nomination to the Supreme Court.</li><li>Judge says life experiences would shape Supreme Court approach.</li><li>Sen. Linds… [+26517 chars]
# --------------------------------------------------
#
# Title: Stocks Fall About 1%, Oil Prices Jump - The Wall Street Journal
#
# Desc: Brent crude prices rise above $120 a barrel; Dow retreats 400 points
#
# Content: U.S. stocks fell and oil prices jumped, as concerns about rising energy prices, supply shortages and inflation rattled investors once again.The S&amp;P 500 ticked down about 0.9% Wednesday, while the… [+6574 chars]
# --------------------------------------------------
#
# Title: Biden seeks new sanctions, help for Ukrainians in Europe - The Associated Press - en Español
#
# Desc: WASHINGTON (AP) — With Europe facing its most precarious future since World War II, President Joe Biden will huddle with key allies in Brussels and Warsaw this week as the leaders try to prevent Russia’s war on Ukraine  from spiraling into an even greater cat…
#
# Content: WASHINGTON (AP) With Europe facing its most precarious future since World War II, President Joe Biden will huddle with key allies in Brussels and Warsaw this week as the leaders try to prevent Russia… [+6949 chars]
# --------------------------------------------------
#
# Title: New Orleans Tornadoes Leave a Path of Destruction - The New York Times
#
# Desc: At least one person was killed, and many houses were destroyed.
#
# Content: Similar scenes played out across St. Bernard Parish on Tuesday night. Neighbors who had helped each other through Hurricane Katrina in 2005, which flooded every house in the parish, pitched in again … [+1084 chars]
# --------------------------------------------------
#
# Title: Nestle to suspend many products in Russia including KitKat - Reuters.com
#
# Desc: Nestle is to halt the sale of a wide range of brands in Russia, including KitKat chocolate bars and Nesquik,amid Ukrainian President Volodymyr Zelenskiy's criticism of the world's biggest food company for its continued presence in the country.
#
# Content: LONDON, March 23 (Reuters) - Nestle is to halt the sale of a wide range of brands in Russia, including KitKat chocolate bars and Nesquik,amid Ukrainian President Volodymyr Zelenskiy's criticism of th… [+3370 chars]
# --------------------------------------------------
#
# Title: Subaqueous foraging among carnivorous dinosaurs - Nature.com
#
# Desc: In extinct species including non-avian dinosaurs, bone density is shown to be a reliable indicator of aquatic behavioural adaptations, which emerged in spinosaurids during the Early Cretaceous.
#
# Content: <li>Kelley, N. P. &amp; Pyenson, N. D. Evolutionary innovation and ecology in marine tetrapods from the Triassic to the Anthropocene. Science348, aaa3716 (2015).
# PubMed
# Google Scholar
# </li><li>G… [+12193 chars]
# --------------------------------------------------
#
# Title: Apple Wallet can hold your Arizona driver's license or state ID - The Verge
#
# Desc: Arizona is the first state to officially roll out support for digital driver’s license and state ID in Apple Wallet. You’ll be able to present the digital IDs at select TSA checkpoints.
#
# Content: More states will follow soon
# Youll be able to hold your phone to a terminal to provide your information.
# Image: Apple
# The first state to officially roll out Apples digital drivers license and sta… [+3344 chars]
# --------------------------------------------------
#
# Title: Harry Styles - Harry's House (coming soon) - Harry Styles
#
# Desc: Album Trailer for Harry Styles' new album "Harry's House" out May 20th.Pre-save / Pre-add the album here: https://hstyles.co.uk Follow Harry Styles:Facebook:...
#
# Content: None
# --------------------------------------------------
#
# Title: Stellantis, LG to invest $4.1 billion in Canadian EV battery plant - CNBC
#
# Desc: The new plant is part of the automaker's plans to accelerate its EV investment to achieve sales of 5 million EVs globally by 2030.
#
# Content: DETROIT Automaker Stellantis and LG Energy Solution will invest about $4.1 billion through a joint venture to establish the first large-scale, domestic, electric vehicle battery manufacturing facilit… [+1236 chars]
# --------------------------------------------------
#
# Title: USMNT World Cup qualifying roundtable Can injury-hit squad do what is needed to reach Qatar? - ESPN
#
# Desc: It all comes down to this: three games between the U.S. and an automatic spot at the World Cup. We break down the key questions and concerns.
#
# Content: The U.S. men's national team has had a interesting relationship with the World Cup. After appearing in three of the first four competitions (1930, 1950, 1954), the Yanks missed the next nine before r… [+17691 chars]
# --------------------------------------------------
#
# Title: Microsoft confirms it was breached by hacker group - CNN
#
# Desc: Microsoft has confirmed it was breached by the hacker group Lapsus$, adding to the cyber gang's growing list of victims.
#
# Content: Microsoft
# (MSFT) has confirmed it was breached by the hacker group Lapsus$, adding to the cyber gangs growing list of victims.
# In a blog post late Tuesday, Microsoft said Lapsus$ had compromised on… [+2156 chars]
# --------------------------------------------------
#
# Title: Davante Adams predicted he would be a star for the Raiders in 3rd grade - Yahoo Sports
#
# Desc: Davante Adams always wanted to play for the Raiders.
#
# Content: Las Vegas Raiders wide receiver Davante Adams always knew he would play for his childhood team. Adams proved Wednesday he really meant it when he said joining the Raiders was "meant to be."
# Adams dr… [+1710 chars]
# --------------------------------------------------
#
# Title: The Caribbean paradises replacing the Queen with Chinese millions - Daily Mail
#
# Desc: The Duke and Duchess of Cambridge's tour of the Caribbean has been overshadowed by protests about the legacy of the British Empire and slavery. Pictured: The couple in Jamaica yesterday.
#
# Content: The Duke and Duchess of Cambridge's tour of the Caribbean has been overshadowed by protests focused on the legacy of the British Empire and slavery in the region.
# In Jamaica the second stop on the e… [+23971 chars]
# --------------------------------------------------
#
# Title: Pamela Anderson Says Her 'Unexpected' Broadway Debut in Chicago Is a 'Moment for Me to Shine' - Yahoo Entertainment
#
# Desc: "I'm doing this for myself, which is rare," she explained
#
# Content: Pamela Anderson is ready for her comeback.
# The Baywatch actress, 54, will soon make her Broadway debut as Roxie Hart — a wannabe vaudevillian who murders a man she is having an affair with and becom… [+2680 chars]
# --------------------------------------------------
#
# Title: Nothing's first smartphone is aimed at Apple, not OnePlus - The Verge
#
# Desc: Nothing will launch its debut smartphone this summer, its CEO and former OnePlus co-founder Carl Pei announced today. It’ll be called the Phone 1, run Android, and be powered by a Qualcomm Snapdragon processor.
#
# Content: Nothing will launch its debut smartphone this summer, its CEO and former OnePlus co-founder Carl Pei announced today during a live stream. Itll be called the Phone 1, run Android, and be powered by a… [+7281 chars]
# --------------------------------------------------
#
# Title: 570K chickens to be destroyed in Nebraska fight against bird flu | TheHill - The Hill
#
# Desc: The Nebraska Department of Agriculture (NDA) announced on Tuesday that it has confirmed...
#
# Content: The Nebraska Department of Agriculture (NDA) announced on Tuesday that it has confirmed a case of the highly contagious bird flu in a commercial flock of 570,000 broiler chickens and that the birds w… [+1407 chars]
# --------------------------------------------------
#
# Title: 100,000 civilians trapped in Mariupol amid Russia’s ‘constant bombing’, says Zelenskiy - The Guardian
#
# Desc: Ukraine president says conditions are ‘inhumane’ in devastated southern city, and accuses Russian forces of seizing convoy on humanitarian corridor
#
# Content: UkraineUkraine president says conditions are inhumane in devastated southern city, and accuses Russian forces of seizing convoy on humanitarian corridor
# Wed 23 Mar 2022 05.26 GMT
# Almost 100,000 peo… [+6316 chars]

# %%
# API_KEY = 'yx39wyiwPNGm7DoDUPCSJB4SzFkr0qurARfbGYyEdaoC'

# URL = 'https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/9e683088-0d12-4399-8118-518f3e60e8c4'
# endpoint = f"{URL}/v1/analyze"
# username = "apikey"
# password = API_KEY

# parameters = {
#     'features': 'emotion,sentiment',
#     'version' : '2020-08-01',
#     'text': desc,
#     'language' : 'en'
# }

# resp = r.get(endpoint, params=parameters, auth=(username, password))

# %%
# import xmltodict

# url = 'http://export.arxiv.org/api/query'

# params = {
#     'search_query' : 'au:david'
# }dd

# resp = r.get(url, params=params)
# res = dict(xmltodict.parse(resp.content))
# res['feed']['id']

# print(resp.text)

# %% [markdown]
# ## Google Maps
# https://developers.google.com/maps/documentation/geocoding/start

# %%
url = 'https://maps.googleapis.com/maps/api/geocode/json' 

address = 'Uppsala Ekonomikum'

params = {
    'address': address,
    'key': 'AIzaSyAwAQwNRabOhjJxgB9zkogV-BKgbAnjxUk'
}

resp = r.get(url, params = params)
data = resp.json()

# %% [markdown]
# ## Yelp API
#
# https://www.yelp.com/developers/documentation/v3/business_search
#
# https://www.yelp.com/developers/documentation/v3/authentication

# %%
# key = 'iI4dsdXt-g13ESGVicCEP7g8svwE657yNKQtQx0UXtrjgteJuPjddz_RYf92YIWiUJxpMx_To53E2hXoMQmnpOSc3Jws0L7SAQTH2Qdno9XFlOih236mUlx6AIEhW3Yx'

key = 'ghDOEjzopHiDK7mmH988M7zt1zMffm6UnZyh-Mgc4kggnnhRYKxm5jvaNbPWbbTmPf8EUkdAoMXUjsmFYs38cFgPLi7CWpRtO8ot_4YoKBEw73UAn5AAKMp2JwI5YnYx'

# header
headers = {'Authorization': 'Bearer ' + key}

url = 'https://api.yelp.com/v3/businesses/search'

parameters = {
    "latitude": lat,
    "longitude" : lon,
    'radius' : 500,
    'categories' : 'food, All'
}

resp = r.get(url, headers=headers, params=parameters)
data = resp.json()

data.keys()
data['businesses']
# Out:
# [{'id': 'evUdhrweFYPaQpFkbEACCw',
#   'alias': 'karins-skafferi-uppsala',
#   'name': 'Karins skafferi',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xkKXDRuu5bZ6NW7S8bUt5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/karins-skafferi-uppsala?adjust_creative=VKyx7qG8XwSXUISOSpVZ-Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VKyx7qG8XwSXUISOSpVZ-Q',
#   'review_count': 1,
#   'categories': [{'alias': 'delicatessen', 'title': 'Delicatessen'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 59.8632756, 'longitude': 17.6213525},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': 'Geijersgatan 15',
#    'address2': None,
#    'address3': None,
#    'city': 'Uppsala',
#    'zip_code': '752 26',
#    'country': 'SE',
#    'state': 'C',
#    'display_address': ['Geijersgatan 15', '752  26 Uppsala', 'Sweden']},
#   'phone': '+4618555637',
#   'display_phone': '+46 18 55 56 37',
#   'distance': 446.7881059083753},
#  {'id': 'k2w9S8a4Uh_hFymLlzRSsw',
#   'alias': 'café-uroxen-uppsala',
#   'name': 'Café Uroxen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/am4JR4g-4i2EL_UQWmnmww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caf%C3%A9-uroxen-uppsala?adjust_creative=VKyx7qG8XwSXUISOSpVZ-Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=VKyx7qG8XwSXUISOSpVZ-Q',
#   'review_count': 1,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 59.8586197, 'longitude': 17.6274395},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': 'S:T Johannesgatan 18',
#    'address2': None,
#    'address3': None,
#    'city': 'Uppsala',
#    'zip_code': '753 12',
#    'country': 'SE',
#    'state': 'C',
#    'display_address': ['S:T Johannesgatan 18', '753  12 Uppsala', 'Sweden']},
#   'phone': '+4618133107',
#   'display_phone': '+46 18 13 31 07',
#   'distance': 337.63177337949014}]

# %% [markdown]
# ## FRED St. Louis Fed
#
# https://fred.stlouisfed.org/docs/api/fred/#General_Documentation

# %%
import pandas as pd

# %%
api_key = '43c439412ffc329ce9e644b6382e35a8'

url_info = 'https://api.stlouisfed.org/fred/series'
url_obs = 'https://api.stlouisfed.org/fred/series/observations'


params = {
    'api_key' : api_key,
    'series_id' : 'GNPCA',
    'file_type' : 'json',
}


resp_info = r.get(url_info, params=params)
resp_obs = r.get(url_obs, params=params)

info = resp_info.json()
data = resp_obs.json()

df = pd.DataFrame(data['observations'])

title = info['seriess'][0]['title']
units = info['seriess'][0]['units']

print(title)
print(units)

display(df)
# Out:
# Real Gross National Product
# Billions of Chained 2012 Dollars
#    realtime_start realtime_end        date      value
# 0      2022-03-23   2022-03-23  1929-01-01   1120.718
# 1      2022-03-23   2022-03-23  1930-01-01   1025.678
# 2      2022-03-23   2022-03-23  1931-01-01    958.927
# 3      2022-03-23   2022-03-23  1932-01-01    834.769
# 4      2022-03-23   2022-03-23  1933-01-01    823.628
# ..            ...          ...         ...        ...
# 87     2022-03-23   2022-03-23  2016-01-01  17901.894
# 88     2022-03-23   2022-03-23  2017-01-01  18354.584
# 89     2022-03-23   2022-03-23  2018-01-01  18874.582
# 90     2022-03-23   2022-03-23  2019-01-01   19271.92
# 91     2022-03-23   2022-03-23  2020-01-01  18582.295
#
# [92 rows x 4 columns]
